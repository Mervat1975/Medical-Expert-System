# %%
# !pip install expertia
# !pip install ipywidgets
from experta import *
# Out:
# ERROR: Could not find a version that satisfies the requirement expertia
# ERROR: No matching distribution found for expertia
# ...

# %%
diseases_list = []
diseases_symptoms = []
symptom_map = {}

def header():
	print("************************************************")
	print("*********Medical Expert System******************")
	print("Group#1 :Mervat Mustafa, Kartik Sharma, Shraddha Khadepatil, Shariq Shaikh")
	print("************************************************")

def preprocess():
	global diseases_list,diseases_symptoms,symptom_map
	diseases = open("diseases.txt")
	diseases_t = diseases.read()
	diseases_list = diseases_t.split("\n")
	diseases.close()
	for disease in diseases_list:
		disease_s_file = open("Disease symptoms/" + disease + ".txt")
		disease_s_data = disease_s_file.read()
		s_list = disease_s_data.split("\n")
		diseases_symptoms.append(s_list)
		symptom_map[str(s_list)] = disease
		disease_s_file.close()
        
def if_not_matched(disease):
		print("")
		print("The most probable disease that you have is %s\n" %(disease))

# %%
from pyknow import KnowledgeEngine
from pyknow import Rule
from pyknow import Fact
from pyknow import DefFacts
from pyknow import W # Wildcard Field Constraint
from pyknow import NOT # matching the absence of a given Fact/Pattern
from pyknow import MATCH
import ipywidgets as widgets

# %%
global symptoms_dict
global personal_info
# @my_decorator is just a way of saying just_some_function = my_decorator(just_some_function)
#def identify_disease(headache, back_pain, chest_pain, cough, fainting, sore_throat, fatigue, restlessness,low_body_temp ,fever,sunken_eyes):
class MedicalChatbot(KnowledgeEngine):
    
	def set_params(self, symptoms_dict, personal_info):
		self.symptoms_dict = symptoms_dict
		self.personal_info = personal_info
    
	@DefFacts()
	def _initial_action(self):
		print("Thank you for using the medical expert systemt.")
		yield Fact(action="find_disease")

	@Rule(Fact(action='find_disease'), NOT(Fact(MATCH.name)),salience = 400)
	def info_0(self):
		self.declare(Fact(name=self.personal_info.get('name')))

	@Rule(Fact(action='find_disease'), NOT(Fact(MATCH.age)),salience = 300)
	def info_1(self):
		self.declare(Fact(age=int(self.personal_info.get('age'))))
		
	@Rule(Fact(action='find_disease'), NOT(Fact(MATCH.gender)),salience = 200)
	def info_2(self):
		self.declare(Fact(gender=self.personal_info.get('gender')))
		
	@Rule(Fact(action='find_disease'), NOT(Fact(MATCH.headache)),salience = 100)
	def symptom_0(self):
		self.declare(Fact(headache=self.symptoms_dict.get('headache')))  

	@Rule(Fact(action='find_disease'), NOT(Fact(MATCH.back_pain)),salience = 100)
	def symptom_1(self):
		self.declare(Fact(back_pain=self.symptoms_dict.get('back_pain')))

	@Rule(Fact(action='find_disease'), NOT(Fact(MATCH.chest_pain)),salience = 100)
	def symptom_2(self):
		self.declare(Fact(chest_pain=self.symptoms_dict.get('chest_pain')))

	@Rule(Fact(action='find_disease'), NOT(Fact(MATCH.cough)),salience = 100)
	def symptom_3(self): 
		self.declare(Fact(cough=self.symptoms_dict.get('cough')))

	@Rule(Fact(action='find_disease'), NOT(Fact(MATCH.fainting)),salience = 100)
	def symptom_4(self):
		self.declare(Fact(fainting=self.symptoms_dict.get('fainting')))

	@Rule(Fact(action='find_disease'), NOT(Fact(MATCH.sore_throat)),salience = 100)
	def symptom_5(self):
		self.declare(Fact(fatigue=self.symptoms_dict.get('fatigue')))
	 
	@Rule(Fact(action='find_disease'), NOT(Fact(MATCH.fatigue)),salience = 100)
	def symptom_6(self):
		self.declare(Fact(sunken_eyes=self.symptoms_dict.get('sunken_eyes')))
	
	@Rule(Fact(action='find_disease'), NOT(Fact(MATCH.low_body_temp)),salience = 100)
	def symptom_7(self):
		self.declare(Fact(low_body_temp=self.symptoms_dict.get('low_body_temperature')))
	
	@Rule(Fact(action='find_disease'), NOT(Fact(MATCH.restlessness)),salience = 100)
	def symptom_8(self):
		self.declare(Fact(restlessness=self.symptoms_dict.get('restlessness')))
	
	@Rule(Fact(action='find_disease'), NOT(Fact(MATCH.sore_throat)),salience = 100)
	def symptom_9(self):
		self.declare(Fact(sore_throat=self.symptoms_dict.get('sore_throat')))
	
	@Rule(Fact(action='find_disease'), NOT(Fact(MATCH.fever)),salience = 100)
	def symptom_10(self):
		self.declare(Fact(fever=self.symptoms_dict.get('fever')))

	@Rule(Fact(action='find_disease'), NOT(Fact(MATCH.nausea)),salience = 100)
	def symptom_11(self):
		self.declare(Fact(nausea=self.symptoms_dict.get('nausea')))

	@Rule(Fact(action='find_disease'), NOT(Fact(MATCH.blurred_vision)),salience = 100)
	def symptom_12(self):
		self.declare(Fact(blurred_vision=self.symptoms_dict.get('blurred_vision')))
        
	@Rule(Fact(action='find_disease'), NOT(Fact(MATCH.breathlessness)),salience = 100)
	def symptom_13(self):
		self.declare(Fact(breathlessness=self.symptoms_dict.get('breathlessness')))

	@Rule(Fact(action='find_disease'),Fact(headache="no"),Fact(back_pain="no"),Fact(chest_pain="no"),Fact(cough="no"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="yes"),Fact(restlessness="no"),Fact(low_body_temp="no"),Fact(fever="yes"),Fact(sunken_eyes="no"),Fact(nausea="yes"),Fact(blurred_vision="no"),Fact(breathlessness="no"))
	def disease_0(self):
		self.declare(Fact(disease="Jaundice"))

	@Rule(Fact(action='find_disease'),Fact(headache="no"),Fact(back_pain="no"),Fact(chest_pain="no"),Fact(cough="no"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="no"),Fact(restlessness="yes"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(sunken_eyes="no"),Fact(nausea="no"),Fact(blurred_vision="no"),Fact(breathlessness="no"))
	def disease_1(self):
		self.declare(Fact(disease="Alzheimers"))

	@Rule(Fact(action='find_disease'),Fact(headache="no"),Fact(back_pain="yes"),Fact(chest_pain="no"),Fact(cough="no"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="yes"),Fact(restlessness="no"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(sunken_eyes="no"),Fact(nausea="no"),Fact(blurred_vision="no"),Fact(breathlessness="no"))
	def disease_2(self):
		self.declare(Fact(disease="Arthritis"))

	@Rule(Fact(action='find_disease'),Fact(headache="no"),Fact(back_pain="no"),Fact(chest_pain="yes"),Fact(cough="yes"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="no"),Fact(restlessness="no"),Fact(low_body_temp="no"),Fact(fever="yes"),Fact(sunken_eyes="no"),Fact(nausea="no"),Fact(blurred_vision="no"),Fact(breathlessness="no"))
	def disease_3(self):
		self.declare(Fact(disease="Tuberculosis"))

	@Rule(Fact(action='find_disease'),Fact(headache="no"),Fact(back_pain="no"),Fact(chest_pain="yes"),Fact(cough="yes"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="no"),Fact(restlessness="yes"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(sunken_eyes="no"),Fact(nausea="no"),Fact(blurred_vision="no"),Fact(breathlessness="no"))
	def disease_4(self):
		self.declare(Fact(disease="Asthma"))

	@Rule(Fact(action='find_disease'),Fact(headache="yes"),Fact(back_pain="no"),Fact(chest_pain="no"),Fact(cough="yes"),Fact(fainting="no"),Fact(sore_throat="yes"),Fact(fatigue="no"),Fact(restlessness="no"),Fact(low_body_temp="no"),Fact(fever="yes"),Fact(sunken_eyes="no"),Fact(nausea="no"),Fact(blurred_vision="no"),Fact(breathlessness="no"))
	def disease_5(self):
		self.declare(Fact(disease="Sinusitis"))

	@Rule(Fact(action='find_disease'),Fact(headache="no"),Fact(back_pain="no"),Fact(chest_pain="no"),Fact(cough="no"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="yes"),Fact(restlessness="no"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(sunken_eyes="no"),Fact(nausea="no"),Fact(blurred_vision="no"),Fact(breathlessness="no"))
	def disease_6(self):
		self.declare(Fact(disease="Epilepsy"))

	@Rule(Fact(action='find_disease'),Fact(headache="no"),Fact(back_pain="no"),Fact(chest_pain="yes"),Fact(cough="no"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="no"),Fact(restlessness="no"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(sunken_eyes="no"),Fact(nausea="yes"),Fact(blurred_vision="no"),Fact(breathlessness="no"))
	def disease_7(self):
		self.declare(Fact(disease="Heart Disease"))

	@Rule(Fact(action='find_disease'),Fact(headache="no"),Fact(back_pain="no"),Fact(chest_pain="no"),Fact(cough="no"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="yes"),Fact(restlessness="no"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(sunken_eyes="no"),Fact(nausea="yes"),Fact(blurred_vision="yes"),Fact(breathlessness="no"))
	def disease_8(self):
		self.declare(Fact(disease="Diabetes"))

	@Rule(Fact(action='find_disease'),Fact(headache="yes"),Fact(back_pain="no"),Fact(chest_pain="no"),Fact(cough="no"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="no"),Fact(restlessness="no"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(sunken_eyes="no"),Fact(nausea="yes"),Fact(blurred_vision="yes"),Fact(breathlessness="no"))
	def disease_9(self):
		self.declare(Fact(disease="Glaucoma"))

	@Rule(Fact(action='find_disease'),Fact(headache="no"),Fact(back_pain="no"),Fact(chest_pain="no"),Fact(cough="no"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="yes"),Fact(restlessness="no"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(sunken_eyes="no"),Fact(nausea="yes"),Fact(blurred_vision="no"),Fact(breathlessness="no"))
	def disease_10(self):
		self.declare(Fact(disease="Hyperthyroidism"))

	@Rule(Fact(action='find_disease'),Fact(headache="yes"),Fact(back_pain="no"),Fact(chest_pain="no"),Fact(cough="no"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="no"),Fact(restlessness="no"),Fact(low_body_temp="no"),Fact(fever="yes"),Fact(sunken_eyes="no"),Fact(nausea="yes"),Fact(blurred_vision="no"),Fact(breathlessness="no"))
	def disease_11(self):
		self.declare(Fact(disease="Heat Stroke"))

	@Rule(Fact(action='find_disease'),Fact(headache="no"),Fact(back_pain="no"),Fact(chest_pain="no"),Fact(cough="no"),Fact(fainting="yes"),Fact(sore_throat="no"),Fact(fatigue="no"),Fact(restlessness="no"),Fact(low_body_temp="yes"),Fact(fever="no"),Fact(sunken_eyes="no"),Fact(nausea="no"),Fact(blurred_vision="no"),Fact(breathlessness="no"))
	def disease_12(self):
		self.declare(Fact(disease="Hypothermia"))

	@Rule(Fact(action='find_disease'),Fact(headache="no"),Fact(back_pain="no"),Fact(chest_pain="no"),Fact(cough="no"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="no"),Fact(restlessness="no"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(sunken_eyes="no"),Fact(nausea="no"),Fact(blurred_vision="no"),Fact(breathlessness="no"))
	def disease_13(self):
		self.declare(Fact(disease="Healthy"))
        
	@Rule(Fact(action='find_disease'),Fact(headache="yes"),Fact(back_pain="no"),Fact(chest_pain="no"),Fact(cough="no"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="no"),Fact(restlessness="no"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(sunken_eyes="no"),Fact(nausea="yes"),Fact(blurred_vision="no"),Fact(breathlessness="no"))
	def disease_14(self):
		self.declare(Fact(disease="Migraine"))

	@Rule(Fact(action='find_disease'),Fact(headache="no"),Fact(back_pain="no"),Fact(chest_pain="yes"),Fact(cough="yes"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="no"),Fact(restlessness="no"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(sunken_eyes="no"),Fact(nausea="no"),Fact(blurred_vision="no"),Fact(breathlessness="yes"))
	def disease_15(self):
		self.declare(Fact(disease="Strong Asthma"))

	@Rule(Fact(action='find_disease'),Fact(headache="no"),Fact(back_pain="no"),Fact(chest_pain="no"),Fact(cough="no"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="no"),Fact(restlessness="no"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(sunken_eyes="yes"),Fact(nausea="no"),Fact(blurred_vision="no"),Fact(breathlessness="no"))
	def disease_16(self):
		self.declare(Fact(disease="Enophthalmos"))
        
	@Rule(Fact(action='find_disease'),Fact(headache="yes"),Fact(back_pain="no"),Fact(chest_pain="no"),Fact(cough="yes"),Fact(fainting="no"),Fact(sore_throat="yes"),Fact(fatigue="yes"),Fact(restlessness="no"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(sunken_eyes="no"),Fact(nausea="yes"),Fact(blurred_vision="no"),Fact(breathlessness="yes"))
	def disease_17(self):
		self.declare(Fact(disease="Pharyngitis"))
        
	@Rule(Fact(action='find_disease'),Fact(headache="yes"),Fact(back_pain="no"),Fact(chest_pain="no"),Fact(cough="yes"),Fact(fainting="no"),Fact(sore_throat="yes"),Fact(fatigue="no"),Fact(restlessness="no"),Fact(low_body_temp="no"),Fact(fever="yes"),Fact(sunken_eyes="no"),Fact(nausea="no"),Fact(blurred_vision="no"),Fact(breathlessness="no"))
	def disease_18(self):
		self.declare(Fact(disease="Typhoid"))
        
	@Rule(Fact(action='find_disease'),Fact(headache="yes"),Fact(back_pain="yes"),Fact(chest_pain="no"),Fact(cough="no"),Fact(fainting="no"),Fact(sore_throat="no"),Fact(fatigue="yes"),Fact(restlessness="no"),Fact(low_body_temp="no"),Fact(fever="yes"),Fact(sunken_eyes="no"),Fact(nausea="yes"),Fact(blurred_vision="no"),Fact(breathlessness="no"))
	def disease_19(self):
		self.declare(Fact(disease="Malaria"))
#Multiple Sclerosis
	@Rule(Fact(action='find_disease'),Fact(headache="yes"),Fact(back_pain="no"),Fact(chest_pain="no"),Fact(cough="no"),Fact(fainting="yes"),Fact(sore_throat="no"),Fact(fatigue="yes"),Fact(restlessness="yes"),Fact(low_body_temp="no"),Fact(fever="no"),Fact(sunken_eyes="no"),Fact(nausea="yes"),Fact(blurred_vision="yes"),Fact(breathlessness="no"))
	def disease_20(self):
		self.declare(Fact(disease="Multiple Sclerosis"))

	@Rule(Fact(action='find_disease'),Fact(headache="yes"),Fact(back_pain="yes"),Fact(chest_pain="yes"),Fact(cough="yes"),Fact(fainting="yes"),Fact(sore_throat="yes"),Fact(fatigue="yes"),Fact(restlessness="yes"),Fact(low_body_temp="no"),Fact(fever="yes"),Fact(sunken_eyes="no"),Fact(nausea="yes"),Fact(blurred_vision="no"),Fact(breathlessness="yes"))
	def disease_21(self):
		self.declare(Fact(disease="Covid-19"))
        
	@Rule(Fact(action='find_disease'),Fact(disease=MATCH.disease),Fact(name=MATCH.name),Fact(age=MATCH.age),Fact(gender=MATCH.gender),salience = 0)
	def disease(self, disease,name,age,gender):
		print("")    
		print("Patient Name: ", name)
		print("Patient Age: ", age)
		print("Patient Gender: ", gender)
		print("") 
		print("The most probable disease that you have is %s\n" %(disease))
 
	@Rule(Fact(action='find_disease'),
		  Fact(name=MATCH.name),
		  Fact(age=MATCH.age),
		  Fact(gender=MATCH.gender),
		  Fact(headache=MATCH.headache),
		  Fact(back_pain=MATCH.back_pain),
		  Fact(chest_pain=MATCH.chest_pain),
		  Fact(cough=MATCH.cough),
		  Fact(fainting=MATCH.fainting),
		  Fact(sore_throat=MATCH.sore_throat),
		  Fact(fatigue=MATCH.fatigue),
		  Fact(low_body_temp=MATCH.low_body_temp),
		  Fact(restlessness=MATCH.restlessness),
		  Fact(fever=MATCH.fever),
		  Fact(sunken_eyes=MATCH.sunken_eyes),
		  Fact(nausea=MATCH.nausea),
		  Fact(blurred_vision=MATCH.blurred_vision),
		  Fact(breathlessness=MATCH.breathlessness),NOT(Fact(disease=MATCH.disease)),salience = -1) 

	def not_matched(self,name,headache, back_pain, chest_pain, cough, fainting, sore_throat, fatigue, restlessness,low_body_temp ,fever ,sunken_eyes ,nausea ,blurred_vision,breathlessness):
		print("")
		print( "Sorry",name, "\nDid not find any disease that matches your exact symptoms")
		lis = [headache, back_pain, chest_pain, cough, fainting, sore_throat, fatigue, restlessness,low_body_temp ,fever ,sunken_eyes ,nausea ,blurred_vision,breathlessness]
		max_count = 0
		max_disease = ""
		for key,val in symptom_map.items():
			count = 0
			temp_list = eval(key)
			for j in range(0,len(lis)):
				if(temp_list[j] == lis[j] and lis[j] == "yes"):
					count = count + 1
			if count > max_count:
				max_count = count
				max_disease = val
		if_not_matched(max_disease)

# %%
def perform_diagnosis(personal_info, symptom_list):
	header()    
	preprocess()
	#engine = MedicalChatbot(personal_info, symptom_list)
	engine = MedicalChatbot()
	engine.set_params(personal_info, symptom_list)
	continue_flag=1
	engine.reset()  # Prepare the engine for the execution.
	engine.run()  # Run it!
	#print(engine.facts)

# %%
# generate layout

def generate_layout():
    # left column 
    name = widgets.Text(
        placeholder='Enter a name',
        description='Name:',
    )
    age = widgets.Text(
        placeholder='Enter a number',
        description='Age:',
    )
    gender = widgets.RadioButtons(
        options=['Male', 'Female'],
        description='Gender',
        disabled=False
    )

    left_box = widgets.VBox(children=[name, age, gender])

    # right column
    data = ["chest pain", "Nausea", "low body temperature", "sunken eyes", "sore throat",
           "back pain", "fever", "cough", "fatigue", "headache", "restlessness", "blurred vision", "fainting","breathlessness"]
    checkboxes = [widgets.Checkbox(value=False, description=label) for label in data]
    right_box = widgets.VBox(children=checkboxes)
    
    button = widgets.Button(description="Click to Diagnose")
    output = widgets.Output(layout={'border': '1px solid black'})

    
    third_column = widgets.VBox(children=[button])

    def on_button_clicked(b):
        output.clear_output()
        with output:
            #print(help(check))
            symptoms_list = { check.description.replace(" ", "_").lower(): 'no' if check.value is False else 'yes' for check in checkboxes}
            #print(str(symptoms_list))
            
            personal_info = {'name': name.value, 'age': age.value, 'gender': gender.value}
            
            return perform_diagnosis(symptoms_list,personal_info)

    button.on_click(on_button_clicked)
    third_column = widgets.VBox(children=[button, output])
    
    Hbox = widgets.HBox([left_box, right_box,third_column], layout={'border': '2px solid black', 'background-color':'blue'})
    
    # Click button
    display(Hbox)
    
generate_layout()
